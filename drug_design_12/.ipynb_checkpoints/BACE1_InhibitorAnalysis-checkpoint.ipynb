# %%
# Cell 1: Import necessary libraries and set up the environment
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from rdkit import Chem
from rdkit.Chem import Descriptors

# Suppress warnings
import warnings
warnings.filterwarnings("ignore")

# Set up plotting style
sns.set_style("whitegrid")

# %%
# Cell 2: Define SMILES for known BACE1 inhibitors and other neurological drugs
smiles_dict = {
    "Verubecestat": "CC1(C(=O)NC(=O)NC1=O)C2=CC=C(C=C2)C3=CC(=CC(=C3)S(=O)(=O)N4CCCC4)F",
    "Lanabecestat": "CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCC(CC3)NC(=O)C4(CC4)NC(=O)C5CC5)F",
    "Atabecestat": "CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)NC(=O)C4(CC4)NC(=O)C5CC5",
    "Elenbecestat": "CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)NC(=O)C4(CCCC4)NC(=O)C5CC5",
    "Donepezil": "COC1=C(C=C2C(=C1)CC(=O)N(C2)CC3CCN(CC3)CC4=CC=CC=C4)OC",
    "Memantine": "CC12CC3CC(C1)(CC(C3)(C2)N)C",
    "Rivastigmine": "CCN(C)C(=O)OC1=CC=CC(=C1)C(C)N(C)C",
    "Galantamine": "CN1CCC23C4C1CC5=C2C(=C(C=C5)OC)OC3C(C=C4)O"
}

# Create a DataFrame
df_smiles = pd.DataFrame(list(smiles_dict.items()), columns=["compound", "smiles"])
df_smiles
# Out:
#        compound                                             smiles
# 0  Verubecestat  CC1(C(=O)NC(=O)NC1=O)C2=CC=C(C=C2)C3=CC(=CC(=C...
# 1  Lanabecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCC(CC3...
# 2   Atabecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)N...
# 3  Elenbecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)N...
# 4     Donepezil  COC1=C(C=C2C(=C1)CC(=O)N(C2)CC3CCN(CC3)CC4=CC=...
# 5     Memantine                        CC12CC3CC(C1)(CC(C3)(C2)N)C
# 6  Rivastigmine                 CCN(C)C(=O)OC1=CC=CC(=C1)C(C)N(C)C
# 7   Galantamine         CN1CCC23C4C1CC5=C2C(=C(C=C5)OC)OC3C(C=C4)O

# %%
# Cell 3: Calculate molecular properties using RDKit
def calc_properties(smiles):
    mol = Chem.MolFromSmiles(smiles)
    return {
        "MolWt": Descriptors.ExactMolWt(mol),
        "LogP": Descriptors.MolLogP(mol),
        "HBD": Descriptors.NumHDonors(mol),
        "HBA": Descriptors.NumHAcceptors(mol),
        "PSA": Descriptors.TPSA(mol),
        "RotBonds": Descriptors.NumRotatableBonds(mol)
    }

# Apply the function to each SMILES
properties = df_smiles["smiles"].apply(calc_properties).apply(pd.Series)
df_smiles = pd.concat([df_smiles, properties], axis=1)
df_smiles
# Out:
#        compound                                             smiles  \
# 0  Verubecestat  CC1(C(=O)NC(=O)NC1=O)C2=CC=C(C=C2)C3=CC(=CC(=C...
# 1  Lanabecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCC(CC3...
# 2   Atabecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)N...
# 3  Elenbecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)N...
# 4     Donepezil  COC1=C(C=C2C(=C1)CC(=O)N(C2)CC3CCN(CC3)CC4=CC=...
# 5     Memantine                        CC12CC3CC(C1)(CC(C3)(C2)N)C
# 6  Rivastigmine                 CCN(C)C(=O)OC1=CC=CC(=C1)C(C)N(C)C
# 7   Galantamine         CN1CCC23C4C1CC5=C2C(=C(C=C5)OC)OC3C(C=C4)O
#
#         MolWt     LogP  HBD  HBA     PSA  RotBonds
# 0  445.110770  1.90090  2.0  5.0  112.65       4.0
# 1  499.194106  3.12922  2.0  4.0   95.58       7.0
# 2  467.187877  3.44382  2.0  4.0   95.58       7.0
# 3  495.219178  4.22402  2.0  4.0   95.58       7.0
# 4  394.225643  3.50070  0.0  4.0   42.01       6.0
# 5  179.167400  2.69410  1.0  1.0   26.02       0.0
# 6  250.168128  2.75970  0.0  3.0   32.78       4.0
# 7  299.152144  1.50110  1.0  4.0   41.93       1.0

# %%
# Cell 4: Estimate logS using a simple method based on LogP
def estimate_logs(logp):
    # This is a very rough estimation and should not be used for accurate predictions
    return -0.8 * logp - 0.5

df_smiles['logS'] = df_smiles['LogP'].apply(estimate_logs)
df_smiles['logS'] = df_smiles['logS'].round(3)
df_smiles['logS_warn'] = "Estimated from LogP"

df_smiles
# Out:
#        compound                                             smiles  \
# 0  Verubecestat  CC1(C(=O)NC(=O)NC1=O)C2=CC=C(C=C2)C3=CC(=CC(=C...
# 1  Lanabecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCC(CC3...
# 2   Atabecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)N...
# 3  Elenbecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)N...
# 4     Donepezil  COC1=C(C=C2C(=C1)CC(=O)N(C2)CC3CCN(CC3)CC4=CC=...
# 5     Memantine                        CC12CC3CC(C1)(CC(C3)(C2)N)C
# 6  Rivastigmine                 CCN(C)C(=O)OC1=CC=CC(=C1)C(C)N(C)C
# 7   Galantamine         CN1CCC23C4C1CC5=C2C(=C(C=C5)OC)OC3C(C=C4)O
#
#         MolWt     LogP  HBD  HBA     PSA  RotBonds   logS            logS_warn
# 0  445.110770  1.90090  2.0  5.0  112.65       4.0 -2.021  Estimated from LogP
# 1  499.194106  3.12922  2.0  4.0   95.58       7.0 -3.003  Estimated from LogP
# 2  467.187877  3.44382  2.0  4.0   95.58       7.0 -3.255  Estimated from LogP
# 3  495.219178  4.22402  2.0  4.0   95.58       7.0 -3.879  Estimated from LogP
# 4  394.225643  3.50070  0.0  4.0   42.01       6.0 -3.301  Estimated from LogP
# 5  179.167400  2.69410  1.0  1.0   26.02       0.0 -2.655  Estimated from LogP
# 6  250.168128  2.75970  0.0  3.0   32.78       4.0 -2.708  Estimated from LogP
# 7  299.152144  1.50110  1.0  4.0   41.93       1.0 -1.701  Estimated from LogP

# %%
# Cell 4: Predict logS with soltrannet
import soltrannet as stn

for ix, row in df_smiles.iterrows():
    logS, _, logS_warn = next(stn.predict([row.smiles]))
    df_smiles.at[ix, "logS"] = round(logS, 3)
    df_smiles.at[ix, "logS_warn"] = logS_warn

df_smiles
# Out:
#        compound                                             smiles  \
# 0  Verubecestat  CC1(C(=O)NC(=O)NC1=O)C2=CC=C(C=C2)C3=CC(=CC(=C...
# 1  Lanabecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCC(CC3...
# 2   Atabecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)N...
# 3  Elenbecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)N...
# 4     Donepezil  COC1=C(C=C2C(=C1)CC(=O)N(C2)CC3CCN(CC3)CC4=CC=...
# 5     Memantine                        CC12CC3CC(C1)(CC(C3)(C2)N)C
# 6  Rivastigmine                 CCN(C)C(=O)OC1=CC=CC(=C1)C(C)N(C)C
# 7   Galantamine         CN1CCC23C4C1CC5=C2C(=C(C=C5)OC)OC3C(C=C4)O
#
#         MolWt     LogP  HBD  HBA     PSA  RotBonds   logS logS_warn
# 0  445.110770  1.90090  2.0  5.0  112.65       4.0 -5.227
# 1  499.194106  3.12922  2.0  4.0   95.58       7.0 -5.829
# 2  467.187877  3.44382  2.0  4.0   95.58       7.0 -5.737
# 3  495.219178  4.22402  2.0  4.0   95.58       7.0 -6.026
# 4  394.225643  3.50070  0.0  4.0   42.01       6.0 -3.875
# 5  179.167400  2.69410  1.0  1.0   26.02       0.0 -2.017
# 6  250.168128  2.75970  0.0  3.0   32.78       4.0 -1.736
# 7  299.152144  1.50110  1.0  4.0   41.93       1.0 -2.605

# %%
# Cell 5: Create plots for molecular properties including logS
properties_to_plot = ["MolWt", "LogP", "HBD", "HBA", "PSA", "RotBonds", "logS"]

f, axs = plt.subplots(len(properties_to_plot), 1, figsize=(12, 4*len(properties_to_plot)), constrained_layout=True)

for i, prop in enumerate(properties_to_plot):
    sns.barplot(data=df_smiles, x="compound", y=prop, ax=axs[i])
    axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=45, ha='right')
    axs[i].set_title(f"{prop} for BACE1 inhibitors and other neurological drugs")

plt.tight_layout()
plt.show()

# %%
# Cell 6: Create a correlation heatmap
correlation_matrix = df_smiles[properties_to_plot].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1, center=0)
plt.title("Correlation Heatmap of Molecular Properties")
plt.tight_layout()
plt.show()

# %%
# Cell 7: Analyze BACE1 inhibitors separately
bace1_inhibitors = ["Verubecestat", "Lanabecestat", "Atabecestat", "Elenbecestat"]
df_bace1 = df_smiles[df_smiles["compound"].isin(bace1_inhibitors)]

f, axs = plt.subplots(len(properties_to_plot), 1, figsize=(10, 4*len(properties_to_plot)), constrained_layout=True)

for i, prop in enumerate(properties_to_plot):
    sns.barplot(data=df_bace1, x="compound", y=prop, ax=axs[i])
    axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=45, ha='right')
    axs[i].set_title(f"{prop} for BACE1 inhibitors")

plt.tight_layout()
plt.show()

# %%
# Cell 9: Inspect DataFrame
print(df_smiles.columns)
print(df_smiles.head())
# Out:
# Index(['compound', 'smiles', 'MolWt', 'LogP', 'HBD', 'HBA', 'PSA', 'RotBonds',
#        'logS', 'logS_warn', 'is_bace1_inhibitor'],
#       dtype='object')
#        compound                                             smiles  \
# 0  Verubecestat  CC1(C(=O)NC(=O)NC1=O)C2=CC=C(C=C2)C3=CC(=CC(=C...
# 1  Lanabecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCC(CC3...
# 2   Atabecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)N...
# 3  Elenbecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)N...
# 4     Donepezil  COC1=C(C=C2C(=C1)CC(=O)N(C2)CC3CCN(CC3)CC4=CC=...
#
#         MolWt     LogP  HBD  HBA     PSA  RotBonds   logS logS_warn  \
# 0  445.110770  1.90090  2.0  5.0  112.65       4.0 -5.227
# 1  499.194106  3.12922  2.0  4.0   95.58       7.0 -5.829
# 2  467.187877  3.44382  2.0  4.0   95.58       7.0 -5.737
# 3  495.219178  4.22402  2.0  4.0   95.58       7.0 -6.026
# 4  394.225643  3.50070  0.0  4.0   42.01       6.0 -3.875
#
#    is_bace1_inhibitor
# 0                True
# 1                True
# 2                True
# 3                True
# 4               False

# %%
# Cell 9: Create 'is_bace1_inhibitor' column and normalized data
bace1_inhibitors = ["Verubecestat", "Lanabecestat", "Atabecestat", "Elenbecestat"]
df_smiles['is_bace1_inhibitor'] = df_smiles['compound'].isin(bace1_inhibitors)

# Select only numeric columns for normalization
numeric_columns = ['MolWt', 'LogP', 'HBD', 'HBA', 'PSA', 'RotBonds', 'logS']
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(df_smiles[numeric_columns])

# Create a new DataFrame with normalized data and 'is_bace1_inhibitor' column
df_normalized = pd.DataFrame(normalized_data, columns=numeric_columns, index=df_smiles.index)
df_normalized['is_bace1_inhibitor'] = df_smiles['is_bace1_inhibitor']
df_normalized['compound'] = df_smiles['compound']

# Create a parallel coordinates plot
plt.figure(figsize=(12, 6))
pd.plotting.parallel_coordinates(
    df_normalized,
    'is_bace1_inhibitor',
    cols=numeric_columns,
    colormap=plt.cm.Set2
)
plt.title("Parallel Coordinates Plot of Molecular Properties")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Print the first few rows of df_normalized to verify its content
print(df_normalized.head())
# Out:
#       MolWt      LogP  HBD   HBA       PSA  RotBonds      logS  \
# 0  0.831004  0.146828  1.0  1.00  1.000000  0.571429  0.186247
# 1  1.000000  0.597932  1.0  0.75  0.802955  1.000000  0.045921
# 2  0.899989  0.713469  1.0  0.75  0.802955  1.000000  0.067366
# 3  0.987579  1.000000  1.0  0.75  0.802955  1.000000  0.000000
# 4  0.672001  0.734359  0.0  0.75  0.184578  0.857143  0.501399
#
#    is_bace1_inhibitor      compound
# 0                True  Verubecestat
# 1                True  Lanabecestat
# 2                True   Atabecestat
# 3                True  Elenbecestat
# 4               False     Donepezil

# %%
# Cell 10: Analyze logS distribution
plt.figure(figsize=(10, 6))
sns.histplot(data=df_smiles, x="logS", hue="is_bace1_inhibitor", kde=True)
plt.title("Distribution of logS Values")
plt.xlabel("logS")
plt.legend(["Other Neurological Drugs", "BACE1 Inhibitors"])
plt.show()

# %%
# Cell 11: Boxplot comparison of properties
properties_to_plot = ['MolWt', 'LogP', 'HBD', 'HBA', 'PSA', 'RotBonds', 'logS']

f, axs = plt.subplots(len(properties_to_plot), 1, figsize=(10, 4*len(properties_to_plot)), constrained_layout=True)

for i, prop in enumerate(properties_to_plot):
    sns.boxplot(data=df_smiles, x="is_bace1_inhibitor", y=prop, ax=axs[i])
    axs[i].set_xticklabels(["Other Neurological Drugs", "BACE1 Inhibitors"])
    axs[i].set_title(f"{prop}: BACE1 Inhibitors vs Other Neurological Drugs")

plt.tight_layout()
plt.show()

# %%
# Cell 13: Calculate FDA_approved_drug_range

import pandas as pd
import numpy as np

# Function to calculate 5th and 95th percentiles
def q5_q95(x):
    return pd.Series({'q5': np.percentile(x, 5), 'q95': np.percentile(x, 95)})

# Assuming non-BACE1 inhibitors are FDA-approved drugs
fda_approved = df_smiles[~df_smiles['is_bace1_inhibitor']]

# Calculate the range for FDA-approved drugs
FDA_approved_drug_range = fda_approved[['logS', 'LogP']].agg(q5_q95).T

print("FDA Approved Drug Ranges:")
print(FDA_approved_drug_range)

# Now let's create the plot with this information

import matplotlib.pyplot as plt
import seaborn as sns

# Define the properties we want to plot
solubility_props = ['logS']
permeability_props = ['LogP']  # Using LogP as a proxy for permeability

# Combine both property sets
all_props = solubility_props + permeability_props

# Create a melted DataFrame for easier plotting
df_melt = df_smiles.melt(id_vars=['compound', 'is_bace1_inhibitor'], 
                         value_vars=all_props, 
                         var_name='Property', 
                         value_name='Value')

# Create the plot
plt.figure(figsize=(12, 6))

# Plot box plots for each property
sns.boxplot(data=df_melt, x='Property', y='Value', hue='is_bace1_inhibitor', 
            dodge=True, whis=[0, 100], width=.6, palette="Set3")

# Add strip plots on top of box plots
sns.stripplot(data=df_melt, x='Property', y='Value', hue='is_bace1_inhibitor', 
              dodge=True, jitter=True, alpha=0.7, color='black')

# Customize the plot
plt.title('Solubility and Permeability Properties of BACE1 Inhibitors vs Other Drugs', fontsize=16)
plt.xlabel('Property', fontsize=14)
plt.ylabel('Value', fontsize=14)
plt.legend(title='BACE1 Inhibitor', labels=['No', 'Yes'], title_fontsize='13', fontsize='12')

# Add FDA approved drug ranges
for n, prop in enumerate(all_props):
    if prop in FDA_approved_drug_range.index:
        plt.hlines(y=FDA_approved_drug_range.loc[prop, 'q5'], xmin=n-0.4, xmax=n+0.4, 
                   colors='red', linestyles='dashed', label='FDA 5th-95th percentile')
        plt.hlines(y=FDA_approved_drug_range.loc[prop, 'q95'], xmin=n-0.4, xmax=n+0.4, 
                   colors='red', linestyles='dashed')

plt.tight_layout()
plt.show()

# Print some statistics
for prop in all_props:
    bace1_values = df_smiles[df_smiles['is_bace1_inhibitor']][prop]
    other_values = df_smiles[~df_smiles['is_bace1_inhibitor']][prop]
    
    print(f"\n{prop} statistics:")
    print(f"BACE1 Inhibitors - Mean: {bace1_values.mean():.2f}, Median: {bace1_values.median():.2f}")
    print(f"Other Drugs - Mean: {other_values.mean():.2f}, Median: {other_values.median():.2f}")
# Out:
# FDA Approved Drug Ranges:
#            q5      q95
# logS -3.68450 -1.77815
# LogP  1.68005  3.38955
# logS statistics:
# BACE1 Inhibitors - Mean: -5.70, Median: -5.78
# Other Drugs - Mean: -2.56, Median: -2.31
#
# LogP statistics:
# BACE1 Inhibitors - Mean: 3.17, Median: 3.29
# Other Drugs - Mean: 2.61, Median: 2.73

# %%
# Cell 13: Create plots for solubility and permeability

import matplotlib.pyplot as plt
import seaborn as sns

# Define the properties we want to plot
solubility_props = ['logS']
permeability_props = ['LogP']  # Using LogP as a proxy for permeability

# Combine both property sets
all_props = solubility_props + permeability_props

# Create a melted DataFrame for easier plotting
df_melt = df_smiles.melt(id_vars=['compound', 'is_bace1_inhibitor'], 
                         value_vars=all_props, 
                         var_name='Property', 
                         value_name='Value')

# Create the plot
plt.figure(figsize=(12, 6))

# Plot box plots for each property
sns.boxplot(data=df_melt, x='Property', y='Value', hue='is_bace1_inhibitor', 
            dodge=True, whis=[0, 100], width=.6, palette="Set3")

# Add strip plots on top of box plots
sns.stripplot(data=df_melt, x='Property', y='Value', hue='is_bace1_inhibitor', 
              dodge=True, jitter=True, alpha=0.7, color='black')

# Customize the plot
plt.title('Solubility and Permeability Properties of BACE1 Inhibitors vs Other Drugs', fontsize=16)
plt.xlabel('Property', fontsize=14)
plt.ylabel('Value', fontsize=14)
plt.legend(title='BACE1 Inhibitor', labels=['No', 'Yes'], title_fontsize='13', fontsize='12')

plt.tight_layout()
plt.show()

# Print some statistics
for prop in all_props:
    bace1_values = df_smiles[df_smiles['is_bace1_inhibitor']][prop]
    other_values = df_smiles[~df_smiles['is_bace1_inhibitor']][prop]
    
    print(f"\n{prop} statistics:")
    print(f"BACE1 Inhibitors - Mean: {bace1_values.mean():.2f}, Median: {bace1_values.median():.2f}")
    print(f"Other Drugs - Mean: {other_values.mean():.2f}, Median: {other_values.median():.2f}")
# Out:
# logS statistics:
# BACE1 Inhibitors - Mean: -5.70, Median: -5.78
# Other Drugs - Mean: -2.56, Median: -2.31
#
# LogP statistics:
# BACE1 Inhibitors - Mean: 3.17, Median: 3.29
# Other Drugs - Mean: 2.61, Median: 2.73

# %%
# !pip install mols2grid
# Out:
# Collecting mols2grid
#   Downloading mols2grid-2.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting ipywidgets<8,>=7 (from mols2grid)
#   Downloading ipywidgets-7.8.4-py2.py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=2.11.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from mols2grid) (3.1.4)
# Requirement already satisfied: numpy in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from mols2grid) (1.26.4)
# Requirement already satisfied: pandas in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from mols2grid) (2.2.3)
# Requirement already satisfied: comm>=0.1.3 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from ipywidgets<8,>=7->mols2grid) (0.2.2)
# Collecting ipython-genutils~=0.2.0 (from ipywidgets<8,>=7->mols2grid)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Requirement already satisfied: traitlets>=4.3.1 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from ipywidgets<8,>=7->mols2grid) (5.14.3)
# Collecting widgetsnbextension~=3.6.9 (from ipywidgets<8,>=7->mols2grid)
#   Downloading widgetsnbextension-3.6.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: ipython>=4.0.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from ipywidgets<8,>=7->mols2grid) (8.18.1)
# Collecting jupyterlab-widgets<3,>=1.0.0 (from ipywidgets<8,>=7->mols2grid)
#   Downloading jupyterlab_widgets-1.1.10-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jinja2>=2.11.0->mols2grid) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from pandas->mols2grid) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from pandas->mols2grid) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from pandas->mols2grid) (2024.2)
# Requirement already satisfied: decorator in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (2.18.0)
# Requirement already satisfied: stack-data in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.6.2)
# Requirement already satisfied: typing-extensions in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (4.12.2)
# Requirement already satisfied: exceptiongroup in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (4.9.0)
# Requirement already satisfied: six>=1.5 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->mols2grid) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (7.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.8.4)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (6.4.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.7.0)
# Requirement already satisfied: wcwidth in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (2.4.1)
# Requirement already satisfied: pure-eval in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.2.3)
# Requirement already satisfied: anyio>=3.1.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (4.6.2)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (24.1)
# Requirement already satisfied: prometheus-client>=0.9 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.21.0)
# Requirement already satisfied: pyzmq>=24 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.27.2)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (8.5.0)
# Requirement already satisfied: ipykernel>=6.5.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (2.2.5)
# Requirement already satisfied: setuptools>=40.1.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (75.1.0)
# Requirement already satisfied: tomli>=1.2.2 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (2.0.1)
# Requirement already satisfied: babel>=2.10 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (21.2.0)
# Requirement already satisfied: certifi in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (3.20.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (1.8.7)
# Requirement already satisfied: nest-asyncio in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (1.6.0)
# Requirement already satisfied: psutil in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (6.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (4.3.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (6.1.0)
# Requirement already satisfied: defusedxml in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (1.5.0)
# Requirement already satisfied: tinycss2 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (2.2.3)
# Requirement already satisfied: webencodings in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (0.5.1)
# Requirement already satisfied: fqdn in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (1.5.1)
# Requirement already satisfied: isoduration in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (3.0.0)
# Requirement already satisfied: uri-template in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (2.5)
# Requirement already satisfied: pycparser in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/cesco345/anaconda3/envs/bace1_research/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7->mols2grid) (2.9.0.20241003)
# Downloading mols2grid-2.0.0-py3-none-any.whl (107 kB)
# Downloading ipywidgets-7.8.4-py2.py3-none-any.whl (124 kB)
# Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Downloading jupyterlab_widgets-1.1.10-py3-none-any.whl (238 kB)
# Downloading widgetsnbextension-3.6.9-py2.py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 12.8 MB/s eta 0:00:00
# Installing collected packages: ipython-genutils, jupyterlab-widgets, widgetsnbextension, ipywidgets, mols2grid
# Successfully installed ipython-genutils-0.2.0 ipywidgets-7.8.4 jupyterlab-widgets-1.1.10 mols2grid-2.0.0 widgetsnbextension-3.6.9

# %%
# Cell 14: Prepare the data
import pandas as pd
import numpy as np

# First, let's properly set the 'is_bace1_inhibitor' column
bace1_inhibitors = ["Verubecestat", "Lanabecestat", "Atabecestat", "Elenbecestat"]
df_smiles['is_bace1_inhibitor'] = df_smiles['compound'].isin(bace1_inhibitors)

# Convert boolean to string for better display
df_smiles['is_bace1_inhibitor'] = df_smiles['is_bace1_inhibitor'].map({True: 'Yes', False: 'No'})

# Round float values for better display
df_display = df_smiles.applymap(lambda x: round(x, 3) if isinstance(x, float) else x)

print(df_display.head())
# Out:
#        compound                                             smiles    MolWt  \
# 0  Verubecestat  CC1(C(=O)NC(=O)NC1=O)C2=CC=C(C=C2)C3=CC(=CC(=C...  445.111
# 1  Lanabecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCC(CC3...  499.194
# 2   Atabecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)N...  467.188
# 3  Elenbecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)N...  495.219
# 4     Donepezil  COC1=C(C=C2C(=C1)CC(=O)N(C2)CC3CCN(CC3)CC4=CC=...  394.226
#
#     LogP  HBD  HBA     PSA  RotBonds   logS logS_warn is_bace1_inhibitor
# 0  1.901  2.0  5.0  112.65       4.0 -5.227                          Yes
# 1  3.129  2.0  4.0   95.58       7.0 -5.829                          Yes
# 2  3.444  2.0  4.0   95.58       7.0 -5.737                          Yes
# 3  4.224  2.0  4.0   95.58       7.0 -6.026                          Yes
# 4  3.501  0.0  4.0   42.01       6.0 -3.875                           No

# %%
import logging
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Cell 14: Inspect and prepare DataFrame
logger.info("Inspecting and preparing DataFrame")
logger.info(f"DataFrame columns: {df_smiles.columns}")
logger.info(f"DataFrame head:\n{df_smiles.head().to_string()}")

# Cell 15: Create visualizations
logger.info("Creating visualizations")

# Use default style instead of seaborn
plt.style.use('default')

# Create a pair plot for numerical columns
numerical_cols = ['MolWt', 'LogP', 'HBD', 'HBA', 'PSA', 'RotBonds', 'logS']
sns.pairplot(df_smiles, vars=numerical_cols, hue='is_bace1_inhibitor', height=2.5)
plt.tight_layout()
plt.savefig('pairplot.png')
plt.close()
logger.info("Pair plot saved as 'pairplot.png'")

# Create box plots for each property
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
axes = axes.flatten()

for i, col in enumerate(numerical_cols):
    sns.boxplot(x='is_bace1_inhibitor', y=col, data=df_smiles, ax=axes[i])
    axes[i].set_title(col)
    axes[i].set_xlabel('BACE1 Inhibitor')

plt.tight_layout()
plt.savefig('boxplots.png')
plt.close()
logger.info("Box plots saved as 'boxplots.png'")

# Create a correlation heatmap
corr = df_smiles[numerical_cols].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap of Molecular Properties')
plt.tight_layout()
plt.savefig('correlation_heatmap.png')
plt.close()
logger.info("Correlation heatmap saved as 'correlation_heatmap.png'")

# Cell 16: Analyze results
logger.info("Analyzing results")

for col in numerical_cols:
    bace1_values = df_smiles[df_smiles['is_bace1_inhibitor'] == 'Yes'][col]
    other_values = df_smiles[df_smiles['is_bace1_inhibitor'] == 'No'][col]
    
    logger.info(f"\n{col} statistics:")
    logger.info(f"BACE1 Inhibitors - Mean: {bace1_values.mean():.2f}, Median: {bace1_values.median():.2f}")
    logger.info(f"Other Drugs - Mean: {other_values.mean():.2f}, Median: {other_values.median():.2f}")

logger.info("Analysis complete")
# Out:
# INFO:__main__:Inspecting and preparing DataFrame
# INFO:__main__:DataFrame columns: Index(['compound', 'smiles', 'MolWt', 'LogP', 'HBD', 'HBA', 'PSA', 'RotBonds',
#        'logS', 'logS_warn', 'is_bace1_inhibitor'],
#       dtype='object')
# INFO:__main__:DataFrame head:
#        compound                                                                     smiles       MolWt     LogP  HBD  HBA     PSA  RotBonds   logS logS_warn is_bace1_inhibitor
# 0  Verubecestat         CC1(C(=O)NC(=O)NC1=O)C2=CC=C(C=C2)C3=CC(=CC(=C3)S(=O)(=O)N4CCCC4)F  445.110770  1.90090  2.0  5.0  112.65       4.0 -5.227                          Yes
# 1  Lanabecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCC(CC3)NC(=O)C4(CC4)NC(=O)C5CC5)F  499.194106  3.12922  2.0  4.0   95.58       7.0 -5.829                          Yes
# 2   Atabecestat      CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)NC(=O)C4(CC4)NC(=O)C5CC5  467.187877  3.44382  2.0  4.0   95.58       7.0 -5.737                          Yes
# 3  Elenbecestat    CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)NC(=O)C4(CCCC4)NC(=O)C5CC5  495.219178  4.22402  2.0  4.0   95.58       7.0 -6.026                          Yes
# 4     Donepezil                     COC1=C(C=C2C(=C1)CC(=O)N(C2)CC3CCN(CC3)CC4=CC=CC=C4)OC  394.225643  3.50070  0.0  4.0   42.01       6.0 -3.875                           No
# INFO:__main__:Creating visualizations
# INFO:__main__:Pair plot saved as 'pairplot.png'
# INFO:__main__:Box plots saved as 'boxplots.png'
# INFO:__main__:Correlation heatmap saved as 'correlation_heatmap.png'
# INFO:__main__:Analyzing results
# INFO:__main__:
# MolWt statistics:
# INFO:__main__:BACE1 Inhibitors - Mean: 476.68, Median: 481.20
# INFO:__main__:Other Drugs - Mean: 280.68, Median: 274.66
# INFO:__main__:
# LogP statistics:
# INFO:__main__:BACE1 Inhibitors - Mean: 3.17, Median: 3.29
# INFO:__main__:Other Drugs - Mean: 2.61, Median: 2.73
# INFO:__main__:
# HBD statistics:
# INFO:__main__:BACE1 Inhibitors - Mean: 2.00, Median: 2.00
# INFO:__main__:Other Drugs - Mean: 0.50, Median: 0.50
# INFO:__main__:
# HBA statistics:
# INFO:__main__:BACE1 Inhibitors - Mean: 4.25, Median: 4.00
# INFO:__main__:Other Drugs - Mean: 3.00, Median: 3.50
# INFO:__main__:
# PSA statistics:
# INFO:__main__:BACE1 Inhibitors - Mean: 99.85, Median: 95.58
# INFO:__main__:Other Drugs - Mean: 35.69, Median: 37.36
# INFO:__main__:
# RotBonds statistics:
# INFO:__main__:BACE1 Inhibitors - Mean: 6.25, Median: 7.00
# INFO:__main__:Other Drugs - Mean: 2.75, Median: 2.50
# INFO:__main__:
# logS statistics:
# INFO:__main__:BACE1 Inhibitors - Mean: -5.70, Median: -5.78
# INFO:__main__:Other Drugs - Mean: -2.56, Median: -2.31
# INFO:__main__:Analysis complete

# %%
import pandas as pd

# Print column names
print("Column names:")
print(df_smiles.columns)

# Print the first few rows
print("\nFirst few rows:")
print(df_smiles.head().to_string())

# Check if 'smiles' or 'SMILES' exists
if 'smiles' in df_smiles.columns:
    print("\n'smiles' column exists")
elif 'SMILES' in df_smiles.columns:
    print("\n'SMILES' column exists")
else:
    print("\nNeither 'smiles' nor 'SMILES' column exists")

# Check data types of columns
print("\nData types:")
print(df_smiles.dtypes)
# Out:
# Column names:
# Index(['compound', 'smiles', 'MolWt', 'LogP', 'HBD', 'HBA', 'PSA', 'RotBonds',
#        'logS', 'logS_warn', 'is_bace1_inhibitor'],
#       dtype='object')
#
# First few rows:
#        compound                                                                     smiles       MolWt     LogP  HBD  HBA     PSA  RotBonds   logS logS_warn is_bace1_inhibitor
# 0  Verubecestat         CC1(C(=O)NC(=O)NC1=O)C2=CC=C(C=C2)C3=CC(=CC(=C3)S(=O)(=O)N4CCCC4)F  445.110770  1.90090  2.0  5.0  112.65       4.0 -5.227                          Yes
# 1  Lanabecestat  CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCC(CC3)NC(=O)C4(CC4)NC(=O)C5CC5)F  499.194106  3.12922  2.0  4.0   95.58       7.0 -5.829                          Yes
# 2   Atabecestat      CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)NC(=O)C4(CC4)NC(=O)C5CC5  467.187877  3.44382  2.0  4.0   95.58       7.0 -5.737                          Yes
# 3  Elenbecestat    CC1=CC=C(C=C1)C2=CC(=CC(=C2)S(=O)(=O)N3CCCC3)NC(=O)C4(CCCC4)NC(=O)C5CC5  495.219178  4.22402  2.0  4.0   95.58       7.0 -6.026                          Yes
# 4     Donepezil                     COC1=C(C=C2C(=C1)CC(=O)N(C2)CC3CCN(CC3)CC4=CC=CC=C4)OC  394.225643  3.50070  0.0  4.0   42.01       6.0 -3.875                           No
#
# 'smiles' column exists
#
# Data types:
# compound               object
# smiles                 object
# MolWt                 float64
# LogP                  float64
# HBD                   float64
# HBA                   float64
# PSA                   float64
# RotBonds              float64
# logS                  float64
# logS_warn              object
# is_bace1_inhibitor     object
# dtype: object

# %%
import mols2grid
from IPython.display import display, HTML

# Define the columns to display in the grid
display_cols = ['compound', 'is_bace1_inhibitor', 'MolWt', 'LogP', 'HBD', 'HBA', 'PSA', 'RotBonds', 'logS']

try:
    # Create the mols2grid display
    grid = mols2grid.display(df_smiles,
                             smiles_col='smiles',
                             subset=display_cols,
                             tooltip=display_cols,
                             tooltip_trigger="hover",
                             tooltip_placement="right",
                             n_cols=3,
                             size=(200, 200))

    # Display the grid in the notebook
    display(grid)  # Changed this line

    # Save the HTML output to a file
    with open("bace1_inhibitors_grid.html", "w") as file:
        file.write(grid._repr_html_())  # Changed this line

    print("The interactive grid has been saved as 'bace1_inhibitors_grid.html'")

except Exception as e:
    print(f"An error occurred: {e}")
    print("Full error traceback:")
    import traceback
    print(traceback.format_exc())
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;
# The interactive grid has been saved as 'bace1_inhibitors_grid.html'

# %% [markdown]
# # BACE1 Inhibitor Analysis for Neurological Disease Research
#
# ## Introduction
#
# This project focuses on analyzing BACE1 (β-site amyloid precursor protein cleaving enzyme 1) inhibitors, which are crucial in Alzheimer's disease research. We employ various computational methods to visualize and analyze the properties of known BACE1 inhibitors compared to other neurological drugs.
#
# ## Data Preparation
#
# ### Steps:
# 1. Loaded data containing BACE1 inhibitors and other neurological drugs
# 2. Inspected the DataFrame structure
# 3. Ensured proper labeling of BACE1 inhibitors
#
# - The dataset includes information on compound names, SMILES representations, and various molecular properties.
# - BACE1 inhibitors were identified and labeled for comparative analysis.
#
# Proper data preparation is crucial for accurate analysis. By correctly labeling BACE1 inhibitors, we enable meaningful comparisons with other neurological drugs, providing insights into the unique properties of these important compounds.
#
# ## Molecular Visualization
#
# ### Steps:
# 1. Used mols2grid to create an interactive grid of molecular structures
# 2. Displayed key properties alongside structures
#
# - The interactive grid allows for visual inspection of molecular structures.
# - Key properties such as molecular weight, LogP, hydrogen bond donors/acceptors, and more are displayed with each structure.
#
# Visual representation of molecular structures aids in identifying common structural features among BACE1 inhibitors. Displaying properties alongside structures allows for quick assessment of structure-property relationships, which is crucial in understanding what makes BACE1 inhibitors effective.
#
# ## Statistical Analysis
#
# ### Steps:
# 1. Calculated basic statistics (mean, median) for each property
# 2. Compared BACE1 inhibitors with other drugs
#
# - Statistics were calculated for properties including molecular weight, LogP, hydrogen bond donors/acceptors, polar surface area, rotatable bonds, and logS.
# - Comparisons reveal key differences between BACE1 inhibitors and other neurological drugs.
#
# Statistical analysis provides quantitative insights into the physicochemical properties that distinguish BACE1 inhibitors from other drugs. These insights are valuable for understanding the characteristics that contribute to BACE1 inhibition and can guide future drug design efforts.
#
# ## Data Visualization
#
# ### Steps:
# 1. Created pair plots to visualize relationships between properties
# 2. Generated box plots to compare distributions
# 3. Produced a correlation heatmap
#
# - Pair plots reveal relationships between different molecular properties.
# - Box plots provide a clear comparison of property distributions.
# - The correlation heatmap identifies relationships between different properties.
#
# These visualizations offer a comprehensive view of the data, allowing for the identification of patterns and trends that might not be apparent from statistics alone. They help in understanding how different properties interact and how BACE1 inhibitors differ from other drugs across multiple dimensions.
#
# ## Conclusion
#
# This analysis provides valuable insights into the physicochemical properties that distinguish BACE1 inhibitors from other neurological drugs. Key findings include:
#
# - BACE1 inhibitors tend to have higher molecular weights and lipophilicity.
# - They consistently have more hydrogen bond donors and slightly more acceptors.
# - BACE1 inhibitors show higher polar surface area and more rotatable bonds.
# - They tend to be less soluble in water.
#
# These insights can guide future drug design efforts for BACE1 inhibition, potentially accelerating the development of new treatments for Alzheimer's disease and other neurological disorders.
#
# ## Future Directions
#
# - Expand the dataset to include more BACE1 inhibitors and other neurological drugs.
# - Incorporate machine learning models to predict BACE1 inhibition based on molecular properties.
# - Investigate the 3D structures of BACE1 inhibitors to understand their binding mechanisms.
# - Extend the analysis to other important targets in neurological disease research.
#
# By leveraging these computational methods and insights, we can potentially accelerate the discovery of new treatments for devastating neurological conditions.
